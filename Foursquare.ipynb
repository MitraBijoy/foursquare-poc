# %% [markdown]
# <a href="https://colab.research.google.com/github/MitraBijoy/foursquare-poc/blob/main/Foursquare.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Imports**

# %%
import requests

# set up Foursquare API credentials
client_id = "ZHYRHGEPX0ABJ4T1NQH5DP5TM52KNVV5BPVXNP3QQUB3LBGN"
client_secret = "TP23NCTJVELKPBBKU4W44D4KXYHLOLEFIHCQ53UPGDFZSRBA"
version = '20220211' # Foursquare API version

# %% [markdown]
# **Extracting Data by point location buffering**

# %%
url = "https://api.foursquare.com/v3/places/search" ##import url from profile

params = {
  "ll": "23.856432331631837,90.07089283401456",
  #	"open_now": "true",
  "sort":"DISTANCE",
    "limit" : "50", # maximum 50
    "radius" : 100000 # maximum 100000
}
## Additional params https://location.foursquare.com/developer/reference/place-search
headers = {
    "Accept": "application/json",
    "Authorization": "fsq3Vo4I5hEAxMlQ/g20xjl+FXb/YBTDUJWX4lAUYkFBKnY=" #Authorization id while creating
}

response = requests.request("GET", url, params=params, headers=headers)

print(response.text)
response.json()
# Out:
# {"results":[{"fsq_id":"4f34bf99e4b0c9801d3783f4","categories":[{"id":16020,"name":"Historic and Protected Site","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_","suffix":".png"}}],"chains":[],"distance":15621,"geocodes":{"main":{"latitude":23.994422,"longitude":90.041543}},"link":"/v3/places/4f34bf99e4b0c9801d3783f4","location":{"country":"BD","cross_street":"","formatted_address":""},"name":"Baliati Jamidar Bari","related_places":{},"timezone":"Asia/Dhaka"},{"fsq_id":"4cd67a1cab19a093ad5f45eb","categories":[{"id":17114,"name":"Shopping Mall","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/shops/mall_","suffix":".png"}}],"chains":[],"distance":19031,"geocodes":{"main":{"latitude":23.849274,"longitude":90.257986}},"link":"/v3/places/4cd67a1cab19a093ad5f45eb","location":{"address":"Savar Bazar","country":"BD","cross_street":"","formatted_address":"Savar Bazar, Savar","locality":"Savar","region":"Dhaka Division"},"name":"Savar City Cent
# ...

# %% [markdown]
# Need to modify the data
# Perfect JSON : https://codebeautify.org/jsonviewer/cb96663c
#
# JSON to CSV : https://data.page/json/csv

# %% [markdown]
# **Extracting Data by rectengle**

# %% [markdown]
# Chittagong City

# %%
url = "https://api.foursquare.com/v3/places/search" ##import url from profile

params = {
    "ne":"22.426747286880232,91.87750779383016",
    "sw":"22.28060714361487,91.77737793580621",
  #	"open_now": "true",
  "sort":"DISTANCE",
    "limit" : "50", # maximum 50
}
## Additional params https://location.foursquare.com/developer/reference/place-search
headers = {
    "Accept": "application/json",
    "Authorization": "fsq3Vo4I5hEAxMlQ/g20xjl+FXb/YBTDUJWX4lAUYkFBKnY=" #Authorization id while creating
}

response = requests.request("GET", url, params=params, headers=headers)

print(response.text)
response.json()
# Out:
# {"results":[{"fsq_id":"535e71d5498eb27f19f507bf","categories":[{"id":13034,"name":"Café","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/cafe_","suffix":".png"}}],"chains":[],"distance":421,"geocodes":{"main":{"latitude":22.350378,"longitude":91.829475}},"link":"/v3/places/535e71d5498eb27f19f507bf","location":{"address":"6 Surson Road","country":"BD","cross_street":"","formatted_address":"6 Surson Road, চট্টগ্রাম","locality":"Chittagong","region":"Chittagong"},"name":"Haatkhola","related_places":{},"timezone":"Asia/Dhaka"},{"fsq_id":"540fe1e9498e888bed70a106","categories":[{"id":11045,"name":"Bank","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/shops/financial_","suffix":".png"}}],"chains":[],"distance":512,"geocodes":{"main":{"latitude":22.358037,"longitude":91.825826}},"link":"/v3/places/540fe1e9498e888bed70a106","location":{"address":"Hotel Peninsula,Nasirabad GEC","country":"BD","cross_street":"","formatted_address":"Hotel Peninsula,Nasirabad GEC"},"name":
# ...

# %% [markdown]
# Barishal

# %%
url = "https://api.foursquare.com/v3/places/search" ##import url from profile

params = {
    "ne":"22.84162043071481,90.61159102710161",
    "sw":"22.159081150654323,89.99477723471497",
  #	"open_now": "true",
  "sort":"DISTANCE",
    "limit" : "50", # maximum 50
}
## Additional params https://location.foursquare.com/developer/reference/place-search
headers = {
    "Accept": "application/json",
    "Authorization": "fsq3Vo4I5hEAxMlQ/g20xjl+FXb/YBTDUJWX4lAUYkFBKnY=" #Authorization id while creating
}

response = requests.request("GET", url, params=params, headers=headers)

print(response.text)
response.json()
# Out:
# {"results":[{"fsq_id":"5430e838498e92eb4a27a2c0","categories":[{"id":17069,"name":"Grocery Store / Supermarket","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_","suffix":".png"}}],"chains":[],"distance":15914,"geocodes":{"main":{"latitude":22.362819,"longitude":90.346388}},"link":"/v3/places/5430e838498e92eb4a27a2c0","location":{"address":"Sadar Road","country":"BD","cross_street":"Pds math","formatted_address":"Sadar Road (Pds math), Patuākhāli - 8600","locality":"Patuākhāli","postcode":"8600","region":"Borishal"},"name":"Patuakhali New Market","related_places":{},"timezone":"Asia/Dhaka"},{"fsq_id":"51c596cd498efc7a32a9aa3b","categories":[{"id":16023,"name":"Lake","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/parks_outdoors/lake_","suffix":".png"}}],"chains":[],"distance":16235,"geocodes":{"main":{"latitude":22.3578,"longitude":90.3378}},"link":"/v3/places/51c596cd498efc7a32a9aa3b","location":{"country":"BD","cross_street":"","formatted_addres
# ...

# %% [markdown]
# Khulna (Near Sundarbans)

# %%
url = "https://api.foursquare.com/v3/places/search" ##import url from profile

params = {
    "ne":"22.611869428214177,89.91336628119114",
    "sw":"22.122948049319234,89.24682116728248",
  #	"open_now": "true",
  "sort":"DISTANCE",
    "limit" : "50", # maximum 50
}
## Additional params https://location.foursquare.com/developer/reference/place-search
headers = {
    "Accept": "application/json",
    "Authorization": "fsq3Vo4I5hEAxMlQ/g20xjl+FXb/YBTDUJWX4lAUYkFBKnY=" #Authorization id while creating
}

response = requests.request("GET", url, params=params, headers=headers)

print(response.text)
response.json()
# Out:
# {"results":[{"fsq_id":"4d1eb6708629224b917b0587","categories":[],"chains":[],"distance":1793,"geocodes":{"main":{"latitude":22.36676,"longitude":89.597529}},"link":"/v3/places/4d1eb6708629224b917b0587","location":{"country":"BD","cross_street":"","formatted_address":""},"name":"Sundarban","related_places":{},"timezone":"Asia/Dhaka"},{"fsq_id":"52ab4470498e00b7de639eac","categories":[{"id":16030,"name":"Other Great Outdoors","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/parks_outdoors/outdoors_","suffix":".png"}}],"chains":[],"distance":4291,"geocodes":{"main":{"latitude":22.377658,"longitude":89.620362}},"link":"/v3/places/52ab4470498e00b7de639eac","location":{"country":"BD","cross_street":"","formatted_address":""},"name":"Sundarbans","related_places":{},"timezone":"Asia/Dhaka"},{"fsq_id":"52ae7a7d498ed2145c9e116e","categories":[{"id":16032,"name":"Park","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_","suffix":".png"}}],"chains":[],"distance
# ...

# %% [markdown]
# Khulna-2(Main City)

# %%
url = "https://api.foursquare.com/v3/places/search" ##import url from profile

params = {
    "ne":"23.190874390024828,89.7036084143119",
    "sw":"22.629284370455704,89.30130031166985",
  #	"open_now": "true",
  "sort":"DISTANCE",
    "limit" : "50", # maximum 50
}
## Additional params https://location.foursquare.com/developer/reference/place-search
headers = {
    "Accept": "application/json",
    "Authorization": "fsq3Vo4I5hEAxMlQ/g20xjl+FXb/YBTDUJWX4lAUYkFBKnY=" #Authorization id while creating
}

response = requests.request("GET", url, params=params, headers=headers)

print(response.text)
response.json()
# Out:
# {"results":[{"fsq_id":"5044a5c8e4b0047a42caceb5","categories":[{"id":11009,"name":"Automotive Service","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/shops/automotive_","suffix":".png"}}],"chains":[],"distance":1075,"geocodes":{"main":{"latitude":22.90047,"longitude":89.501173}},"link":"/v3/places/5044a5c8e4b0047a42caceb5","location":{"country":"BD","formatted_address":""},"name":"KUET Garage","related_places":{},"timezone":"Asia/Dhaka"},{"fsq_id":"504367f1e4b07ecdeadbbf00","categories":[{"id":16017,"name":"Garden","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_","suffix":".png"}}],"chains":[],"distance":1136,"geocodes":{"main":{"latitude":22.899853,"longitude":89.502337}},"link":"/v3/places/504367f1e4b07ecdeadbbf00","location":{"country":"BD","formatted_address":""},"name":"Podmo Pukur","related_places":{},"timezone":"Asia/Dhaka"},{"fsq_id":"51f6c0f5498e108a9e01fb01","categories":[{"id":16017,"name":"Garden","icon":{"prefix":"https://ss3.4sq
# ...
